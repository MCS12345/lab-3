# %% [markdown]
# 184547
# Simeon
# 3 BS MGT

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[    
                  ]
    },
                    
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
    }

def relationship_status(from_member,to_member):
 
    follower = False
    folloSwedby = False
    none = None
    
    if from_member in social_graph[to_member]["following"]:
        followedby = True 

    if to_member in social_graph[from_member]["following"]:
        follower = True

        
    if (followedby == True and follower == True):
        none = "Friends"
    elif (followedby == True and follower == False):
        none = "Followed by"
    elif (followedby == False and follower == True):
        none = "Follower"
    else:
        None
        
    return none
    
relationship_status("@joeilagan","@jobenilagan")
# Out:
# 'Friends'

# %%
board1 = [
['X','X','X'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]


def get_winner(board):
    
    winner = None
    
    for row in board:
        if row.count(row[0]) == len(row) and row[0] != 0:
            winner = row[0]

    for col in range(len(board)):
        c = []       
        for row in board:
            c.append(row[col])
            
        if c.count(c[0]) == len(c) and c[0] != 0:
            winner  = c[0]
            
    d1 = [board[i][i] for i, v in enumerate(board)]
    d2 = [board[2-i][i] for i, v in enumerate(board)]

    if all(num == d1[0] for num in d1):
         winner = d1[0]
    elif all(num == d2[0] for num in d2):
        winner = d2[0]


        
    return winner

get_winner(board6)

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    },
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}


def eta(source,destination):
    time = 0    
    if source == destination:
        return time
    elif(source,destination) in legs:
        time = legs[source,destination]["travel_time_mins"]
        return time
    elif (source,destination) not in legs:

            if source or destination == "admu":
                if source == "admu":
                    time += 35
                elif destination == "admu":
                    time += 10
                    
            if source or destination == "dlsu":
                if source == "dlsu":
                    time += 55
                elif destination == "dlsu":
                    time +=35
            if source or destination == "upd":
                if source == "upd":
                    time += 10
                elif destination == "upd":
                    time += 55
            return time

source = input("Enter source: ")
destination = input("Enter destination: ")

print("ETA " + str(eta(source,destination)))
# Out:
# Enter source: upd
# Enter destination: dlsu
# ETA 45
